# %%
import pandas as pd
import matplotlib.pyplot as plt
# Out:
# C:\Users\Owner\AppData\Roaming\Python\Python313\site-packages\pandas\core\computation\expressions.py:23: UserWarning: Pandas requires version '2.10.2' or newer of 'numexpr' (version '2.10.1' currently installed).
#   from pandas.core.computation.check import NUMEXPR_INSTALLED

# %%
Exoplanet_data = pd.read_csv("C:\\Users\\Owner\\OneDrive\\Documents\\NASA_Projects\\Exoplanet_Project\\Exoplanets.csv")
Exoplanet_df = pd.DataFrame(Exoplanet_data)

# %%
#produce a table from the data frame table from table

print(Exoplanet_df)
# Out:
#          pl_name hostname  default_flag  sy_snum  sy_pnum  discoverymethod  \
# 0       11 Com b   11 Com             0        2        1  Radial Velocity
# 1       11 Com b   11 Com             1        2        1  Radial Velocity
# 2       11 Com b   11 Com             0        2        1  Radial Velocity
# 3       11 UMi b   11 UMi             1        1        1  Radial Velocity
# 4       11 UMi b   11 UMi             0        1        1  Radial Velocity
# ...          ...      ...           ...      ...      ...              ...
# 40101  ups And d  ups And             0        2        3  Radial Velocity
# 40102  ups Leo b  ups Leo             1        1        1  Radial Velocity
# 40103   xi Aql b   xi Aql             1        1        1  Radial Velocity
# 40104   xi Aql b   xi Aql             0        1        1  Radial Velocity
# 40105   xi Aql b   xi Aql             0        1        1  Radial Velocity
#
# ...

# %%
# print column names
Exoplanet_df.columns.values
# Out:
# <ArrowStringArray>
# [        'pl_name',        'hostname',    'default_flag',         'sy_snum',
#          'sy_pnum', 'discoverymethod',       'disc_year',   'disc_facility',
#          'soltype', 'pl_controv_flag',      'pl_refname',       'pl_orbper',
#    'pl_orbpererr1',   'pl_orbpererr2',    'pl_orbperlim',      'pl_orbsmax',
#   'pl_orbsmaxerr1',  'pl_orbsmaxerr2',   'pl_orbsmaxlim',         'pl_rade',
#      'pl_radeerr1',     'pl_radeerr2',      'pl_radelim',         'pl_radj',
#      'pl_radjerr1',     'pl_radjerr2',      'pl_radjlim',       'pl_bmasse',
#    'pl_bmasseerr1',   'pl_bmasseerr2',    'pl_bmasselim',       'pl_bmassj',
#    'pl_bmassjerr1',   'pl_bmassjerr2',    'pl_bmassjlim',    'pl_bmassprov',
#      'pl_orbeccen', 'pl_orbeccenerr1', 'pl_orbeccenerr2',  'pl_orbeccenlim',
#         'pl_insol',    'pl_insolerr1',    'pl_insolerr2',     'pl_insollim',
#           'pl_eqt',      'pl_eqterr1',      'pl_eqterr2',       'pl_eqtlim',
# ...

# %%
# sort the data frame by the hostname in alphabetical order
Exoplanet_df.sort_values(by=['hostname'], inplace=True)

num_rows = 20
Exoplanet_df.head(num_rows)
# Out:
#           pl_name hostname  default_flag  sy_snum  sy_pnum  discoverymethod  \
# 0        11 Com b   11 Com             0        2        1  Radial Velocity
# 1        11 Com b   11 Com             1        2        1  Radial Velocity
# 2        11 Com b   11 Com             0        2        1  Radial Velocity
# 3        11 UMi b   11 UMi             1        1        1  Radial Velocity
# 4        11 UMi b   11 UMi             0        1        1  Radial Velocity
# 5        11 UMi b   11 UMi             0        1        1  Radial Velocity
# 6        14 And b   14 And             1        1        1  Radial Velocity
# 7        14 And b   14 And             0        1        1  Radial Velocity
# 8        14 And b   14 And             0        1        1  Radial Velocity
# 9        14 Her b   14 Her             0        1        2  Radial Velocity
# 10       14 Her b   14 Her             0        1        2  Radial Velocity
# ...
