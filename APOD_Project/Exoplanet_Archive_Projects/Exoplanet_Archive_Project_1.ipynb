# %%
# Anlyze Data in K2_Archive

import pandas as pd
import numpy as np
from matplotlib import pyplot as plt
# Out:
# C:\Users\Owner\AppData\Roaming\Python\Python313\site-packages\pandas\core\computation\expressions.py:23: UserWarning: Pandas requires version '2.10.2' or newer of 'numexpr' (version '2.10.1' currently installed).
#   from pandas.core.computation.check import NUMEXPR_INSTALLED

# %%
K2_Archive = pd.read_csv("K2_Archive.csv")

# %%
K2_Archive
# Out:
#          pl_name hostname  default_flag  sy_snum  sy_pnum  discoverymethod  \
# 0       11 Com b   11 Com             0        2        1  Radial Velocity
# 1       11 Com b   11 Com             1        2        1  Radial Velocity
# 2       11 Com b   11 Com             0        2        1  Radial Velocity
# 3       11 UMi b   11 UMi             1        1        1  Radial Velocity
# 4       11 UMi b   11 UMi             0        1        1  Radial Velocity
# ...          ...      ...           ...      ...      ...              ...
# 40101  ups And d  ups And             0        2        3  Radial Velocity
# 40102  ups Leo b  ups Leo             1        1        1  Radial Velocity
# 40103   xi Aql b   xi Aql             1        1        1  Radial Velocity
# 40104   xi Aql b   xi Aql             0        1        1  Radial Velocity
# 40105   xi Aql b   xi Aql             0        1        1  Radial Velocity
#
# ...

# %%
# Compare Stellar Mass to Planetary Mass

K2_Archive.sort_values(by="st_mass", inplace=True)

# %%
K2_Archive
# Out:
#                      pl_name             hostname  default_flag  sy_snum  \
# 35572    MOA-2011-BLG-262L b    MOA-2011-BLG-262L             0        1
# 35912  OGLE-2016-BLG-1266L b  OGLE-2016-BLG-1266L             0        1
# 35916  OGLE-2016-BLG-1266L b  OGLE-2016-BLG-1266L             0        1
# 35600    MOA-2015-BLG-337L b    MOA-2015-BLG-337L             0        1
# 35598    MOA-2015-BLG-337L b    MOA-2015-BLG-337L             1        1
# ...                      ...                  ...           ...      ...
# 40092              ups And c              ups And             0        2
# 40093              ups And c              ups And             0        2
# 40096              ups And d              ups And             0        2
# 40099              ups And d              ups And             0        2
# 40101              ups And d              ups And             0        2
#
#        sy_pnum  discoverymethod  disc_year           disc_facility  \
# ...

# %%
# Make K2_Archive_df a DataFrame

K2_Archive_df = pd.DataFrame(K2_Archive_df)

# %%
K2_Archive_df
# Out:
#        st_mass  pl_bmassj
# 35572   0.0031   0.001500
# 35912   0.0077   6.090000
# 35916   0.0080   6.190000
# 35600   0.0094   0.106000
# 35598   0.0094   0.106000
# ...        ...        ...
# 40092      NaN   2.054568
# 40093      NaN   1.980000
# 40096      NaN   3.950000
# 40099      NaN   4.335673
# 40101      NaN   3.950000
#
# [40106 rows x 2 columns]

# %%
# Plot Stellar Mass vs Planetary Mass

plt.scatter(K2_Archive_df["st_mass"], K2_Archive_df["pl_bmassj"], color="blue")
